# %%
import matplotlib.pyplot as plt
import pandas as pd

graph=pd.read_csv("all_average.csv")
graph.head(4)




graph['month'] = pd.to_datetime(graph['month'])


cols_plot = [ 'north', 'trans','forest']
axes = graph[cols_plot].plot(subplots=True,color="green")
for label in axes:
    label.set_ylabel('average')
    label.set_xlabel("Month")
plt.savefig('time_graph.jpg')
